# %% [markdown]
# # DESAFIO LATAM

# %% [markdown]
# # FUNDAMENTOS DE DATA SCIENCE

# %% [markdown]
# # DIMENSIONALIDAD

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import stats
import seaborn as sns
from scipy.stats import norm
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('cep45.csv')

# %%
df.head()
# Out:
#    corr  filtro  psu  region  p1_1  p1_2  p1_3  p2  p3  p4  ...  de14_b  \
# 0     1     937  150      13     9     3     6   1   3   2  ...       2
# 1     2     938  150      13     7     6     3   2   2   1  ...       2
# 2     3     939  150      13     3     6     9   2   2   3  ...       2
# 3     4    1096  182      13     3     4    11   3   2   2  ...       2
# 4     5    1097  182      13     6    11     7   3   1   1  ...       2
#
#    de14_c  de14_d  de14_e  de14_f  de15  de16  de17  b5      pond
# 0       2       2       2       2     6     4     4   1  0.782461
# 1       2       1       2       2     8     4     4   1  1.157864
# 2       2       2       2       2     9     6     4   1  1.204037
# 3       2       2       2       2     6     3     3   1  1.025330
# 4       2       2       2       2     6     3     3   1  1.204037
#
# [5 rows x 188 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1503 entries, 0 to 1502
# Columns: 188 entries, corr to pond
# dtypes: float64(34), int64(153), object(1)
# memory usage: 2.2+ MB

# %%
from sklearn.preprocessing import StandardScaler

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/cv/hbvjd10x3wb07tyjdtv7ltgr0000gp/T/ipykernel_43450/435166744.py in <module>
# ----> 1 df_scaled = StandardScaler().fit_transform(df)
#       2 df_scaled = pd.DataFrame(data = df_scaled)
#
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     697         if y is None:
#     698             # fit method of arity 1 (unsupervised transformation)
# --> 699             return self.fit(X, **fit_params).transform(X)
#     700         else:
#     701             # fit method of arity 2 (supervised transformation)
#
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_data.py in fit(self, X, y, sample_weight)
#     728         # Reset internal state before fitting
#     729         self._reset()
# --> 730         return self.partial_fit(X, y, sample_weight)
#     731
#     732     def partial_fit(self, X, y=None, sample_weight=None):
#
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_data.py in partial_fit(self, X, y, sample_weight)
#     764         """
#     765         first_call = not hasattr(self, "n_samples_seen_")
# --> 766         X = self._validate_data(X, accept_sparse=('csr', 'csc'),
#     767                                 estimator=self, dtype=FLOAT_DTYPES,
#     768                                 force_all_finite='allow-nan', reset=first_call)
#
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     419             out = X
#     420         elif isinstance(y, str) and y == 'no_validation':
# --> 421             X = check_array(X, **check_params)
#     422             out = X
#     423         else:
#
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     671                     array = array.astype(dtype, casting="unsafe", copy=False)
#     672                 else:
# --> 673                     array = np.asarray(array, order=order, dtype=dtype)
#     674             except ComplexWarning as complex_warning:
#     675                 raise ValueError("Complex data not supported\n"
#
# /opt/anaconda3/lib/python3.9/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in __array__(self, dtype)
#    1991
#    1992     def __array__(self, dtype: NpDtype | None = None) -> np.ndarray:
# -> 1993         return np.asarray(self._values, dtype=dtype)
#    1994
#    1995     def __array_wrap__(
#
# /opt/anaconda3/lib/python3.9/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# ValueError: could not convert string to float: '1959-05-13T00:00:00Z'

# %%
df.loc[:,'conjunto':'variables'].applymap(lambda x: stats.zscore(x))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'conjunto'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/cv/hbvjd10x3wb07tyjdtv7ltgr0000gp/T/ipykernel_43450/652735588.py in <module>
# ----> 1 df.loc[:,'conjunto':'variables'].applymap(lambda x: stats.zscore(x))
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1107             return self._multi_take(tup)
#    1108
# -> 1109         return self._getitem_tuple_same_dim(tup)
#    1110
#    1111     def _get_label(self, label, axis: int):
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _getitem_tuple_same_dim(self, tup)
#     804                 continue
#     805
# --> 806             retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     807             # We should never have retval.ndim < self.ndim, as that should
#     808             #  be handled by the _getitem_lowerdim call above.
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1140         if isinstance(key, slice):
#    1141             self._validate_key(key, axis)
# -> 1142             return self._get_slice_axis(key, axis=axis)
#    1143         elif com.is_bool_indexer(key):
#    1144             return self._getbool_axis(key, axis=axis)
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _get_slice_axis(self, slice_obj, axis)
#    1174
#    1175         labels = obj._get_axis(axis)
# -> 1176         indexer = labels.slice_indexer(slice_obj.start, slice_obj.stop, slice_obj.step)
#    1177
#    1178         if isinstance(indexer, slice):
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in slice_indexer(self, start, end, step, kind)
#    5683         slice(1, 3, None)
#    5684         """
# -> 5685         start_slice, end_slice = self.slice_locs(start, end, step=step)
#    5686
#    5687         # return a slice
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in slice_locs(self, start, end, step, kind)
#    5885         start_slice = None
#    5886         if start is not None:
# -> 5887             start_slice = self.get_slice_bound(start, "left")
#    5888         if start_slice is None:
#    5889             start_slice = 0
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_slice_bound(self, label, side, kind)
#    5805             except ValueError:
#    5806                 # raise the original KeyError
# -> 5807                 raise err
#    5808
#    5809         if isinstance(slc, np.ndarray):
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_slice_bound(self, label, side, kind)
#    5799         # we need to look up the label
#    5800         try:
# -> 5801             slc = self.get_loc(label)
#    5802         except KeyError as err:
#    5803             try:
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'conjunto'

# %% [markdown]
# # DESAFIO ANALISIS FACTORIAL

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
# %matplotlib inline
import seaborn as sns
import statsmodels.api as sm
import statsmodels.formula.api as smf 
import factor_analyzer as fact 
import missingno as msngo
import warnings
warnings.filterwarnings(action='ignore')
df = pd.read_csv('bfi.csv')
plt.style.use('seaborn') # gráficos estilo seaborn
plt.rcParams["figure.figsize"] = (10, 6) # Tamaño gráficos
plt.rcParams["figure.dpi"] = 200 # resolución gráficos

# %%
df.head()
# Out:
#    Unnamed: 0   A1   A2   A3   A4   A5   C1   C2   C3   C4  ...   N4   N5  \
# 0       61617  2.0  4.0  3.0  4.0  4.0  2.0  3.0  3.0  4.0  ...  2.0  3.0
# 1       61618  2.0  4.0  5.0  2.0  5.0  5.0  4.0  4.0  3.0  ...  5.0  5.0
# 2       61620  5.0  4.0  5.0  4.0  4.0  4.0  5.0  4.0  2.0  ...  2.0  3.0
# 3       61621  4.0  4.0  6.0  5.0  5.0  4.0  4.0  3.0  5.0  ...  4.0  1.0
# 4       61622  2.0  3.0  3.0  4.0  5.0  4.0  4.0  5.0  3.0  ...  4.0  3.0
#
#     O1  O2   O3   O4   O5  gender  education  age
# 0  3.0   6  3.0  4.0  3.0       1        NaN   16
# 1  4.0   2  4.0  3.0  3.0       2        NaN   18
# 2  4.0   2  5.0  5.0  2.0       2        NaN   17
# 3  3.0   3  4.0  3.0  5.0       2        NaN   17
# 4  3.0   3  4.0  3.0  3.0       1        NaN   17
#
# [5 rows x 29 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2800 entries, 0 to 2799
# Data columns (total 28 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   A1         2784 non-null   float64
#  1   A2         2773 non-null   float64
#  2   A3         2774 non-null   float64
#  3   A4         2781 non-null   float64
#  4   A5         2784 non-null   float64
#  5   C1         2779 non-null   float64
#  6   C2         2776 non-null   float64
#  7   C3         2780 non-null   float64
#  8   C4         2774 non-null   float64
#  9   C5         2784 non-null   float64
#  10  E1         2777 non-null   float64
#  11  E2         2784 non-null   float64
#  12  E3         2775 non-null   float64
#  13  E4         2791 non-null   float64
#  14  E5         2779 non-null   float64
#  15  N1         2778 non-null   float64
#  16  N2         2779 non-null   float64
#  17  N3         2789 non-null   float64
#  18  N4         2764 non-null   float64
#  19  N5         2771 non-null   float64
#  20  O1         2778 non-null   float64
#  21  O2         2800 non-null   int64
#  22  O3         2772 non-null   float64
#  23  O4         2786 non-null   float64
#  24  O5         2780 non-null   float64
#  25  gender     2800 non-null   int64
#  26  education  2577 non-null   float64
#  27  age        2800 non-null   int64
# dtypes: float64(25), int64(3)
# memory usage: 612.6 KB

# %%
df = df.drop('Unnamed: 0', axis = 1)

# %%
 msngo.matrix(df);

# %%
for colname, serie in df.iteritems(): 
    print(colname, "NA's %\n") 
    print(serie.isnull().value_counts('%'))
# Out:
# A1 NA's %
#
# False    0.994286
# True     0.005714
# Name: A1, dtype: float64
# A2 NA's %
#
# False    0.990357
# True     0.009643
# Name: A2, dtype: float64
# A3 NA's %
#
# False    0.990714
# True     0.009286
# Name: A3, dtype: float64
# A4 NA's %
#
# False    0.993214
# True     0.006786
# Name: A4, dtype: float64
# A5 NA's %
#
# False    0.994286
# True     0.005714
# Name: A5, dtype: float64
# C1 NA's %
#
# False    0.9925
# True     0.0075
# Name: C1, dtype: float64
# C2 NA's %
#
# False    0.991429
# True     0.008571
# Name: C2, dtype: float64
# C3 NA's %
#
# False    0.992857
# True     0.007143
# Name: C3, dtype: float64
# C4 NA's %
#
# False    0.990714
# True     0.009286
# Name: C4, dtype: float64
# C5 NA's %
#
# False    0.994286
# True     0.005714
# Name: C5, dtype: float64
# E1 NA's %
#
# False    0.991786
# True     0.008214
# Name: E1, dtype: float64
# E2 NA's %
#
# False    0.994286
# True     0.005714
# Name: E2, dtype: float64
# E3 NA's %
#
# False    0.991071
# True     0.008929
# Name: E3, dtype: float64
# E4 NA's %
#
# False    0.996786
# True     0.003214
# Name: E4, dtype: float64
# E5 NA's %
#
# False    0.9925
# True     0.0075
# Name: E5, dtype: float64
# N1 NA's %
#
# False    0.992143
# True     0.007857
# Name: N1, dtype: float64
# N2 NA's %
#
# False    0.9925
# True     0.0075
# Name: N2, dtype: float64
# N3 NA's %
#
# False    0.996071
# True     0.003929
# Name: N3, dtype: float64
# N4 NA's %
#
# False    0.987143
# True     0.012857
# Name: N4, dtype: float64
# N5 NA's %
#
# False    0.989643
# True     0.010357
# Name: N5, dtype: float64
# O1 NA's %
#
# False    0.992143
# True     0.007857
# Name: O1, dtype: float64
# O2 NA's %
#
# False    1.0
# Name: O2, dtype: float64
# O3 NA's %
#
# False    0.99
# True     0.01
# Name: O3, dtype: float64
# O4 NA's %
#
# False    0.995
# True     0.005
# Name: O4, dtype: float64
# O5 NA's %
#
# False    0.992857
# True     0.007143
# Name: O5, dtype: float64
# gender NA's %
#
# False    1.0
# Name: gender, dtype: float64
# education NA's %
#
# False    0.920357
# True     0.079643
# Name: education, dtype: float64
# age NA's %
#
# False    1.0
# Name: age, dtype: float64

# %%
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2236 entries, 5 to 2799
# Data columns (total 28 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   A1         2236 non-null   float64
#  1   A2         2236 non-null   float64
#  2   A3         2236 non-null   float64
#  3   A4         2236 non-null   float64
#  4   A5         2236 non-null   float64
#  5   C1         2236 non-null   float64
#  6   C2         2236 non-null   float64
#  7   C3         2236 non-null   float64
#  8   C4         2236 non-null   float64
#  9   C5         2236 non-null   float64
#  10  E1         2236 non-null   float64
#  11  E2         2236 non-null   float64
#  12  E3         2236 non-null   float64
#  13  E4         2236 non-null   float64
#  14  E5         2236 non-null   float64
#  15  N1         2236 non-null   float64
#  16  N2         2236 non-null   float64
#  17  N3         2236 non-null   float64
#  18  N4         2236 non-null   float64
#  19  N5         2236 non-null   float64
#  20  O1         2236 non-null   float64
#  21  O2         2236 non-null   int64
#  22  O3         2236 non-null   float64
#  23  O4         2236 non-null   float64
#  24  O5         2236 non-null   float64
#  25  gender     2236 non-null   int64
#  26  education  2236 non-null   float64
#  27  age        2236 non-null   int64
# dtypes: float64(25), int64(3)
# memory usage: 506.6 KB

# %%
 msngo.matrix(df);

# %% [markdown]
# # Desafío 3: Descripción

# %%
personality_df = df.loc[:, 'A1':'O5']

# %%
plt.plot(personality_df.mean().sort_values(), "o")

# %%
personality_corrs_abs = personality_df.corr()

# %%
sns.heatmap(personality_corrs_abs, cmap='Greys', vmin=0.0, square=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Desafío 4: Extracción de factores

# %%
fact.calculate_bartlett_sphericity(personality_df)
# Out:
# (16509.6735504972, 0.0)

# %%
fact.calculate_kmo(personality_df)
# Out:
# (array([0.73783211, 0.83426339, 0.87158082, 0.87042369, 0.90061871,
#         0.83810325, 0.78841959, 0.84946345, 0.82364592, 0.86188771,
#         0.84151427, 0.88389524, 0.89307072, 0.87818653, 0.89404239,
#         0.7781268 , 0.77845262, 0.86005895, 0.88625489, 0.86049617,
#         0.85501182, 0.78381059, 0.83374388, 0.78111794, 0.75804877]),
#  0.8468295031833752)

# %%
personality_factor = fact.FactorAnalyzer(n_factors=6) 
personality_factor.fit(personality_df)
# Out:
# FactorAnalyzer(n_factors=6, rotation_kwargs={})

# %%
personality_eigenvalues = personality_factor.get_eigenvalues()[0]

# %%
plt.figure(figsize=(15,10))
plt.scatter(range(1,personality_df.shape[1]+1),personality_eigenvalues)
plt.plot(range(1,personality_df.shape[1]+1), personality_eigenvalues,  'o-', color='tomato')
plt.title('Scree Plot')
plt.xlabel('Factors')
plt.ylabel('Eigenvalue')
plt.axhline(1)
plt.title("Scree plot")
plt.show()

# %%
personality_loadings = personality_factor.loadings_
personality_loadings
# Out:
# array([[ 0.04424599,  0.08732614,  0.10630779,  0.14775216, -0.62321729,
#          0.17473686],
#        [ 0.11368602,  0.17964962,  0.05815394, -0.02598935,  0.63954145,
#         -0.03974232],
#        [ 0.00489421,  0.26906572,  0.02571255,  0.02073193,  0.48993031,
#          0.18680318],
#        [-0.04763319,  0.12925091,  0.19033621,  0.18247103,  0.32484374,
#          0.06007357],
#        [-0.16494203,  0.32359082, -0.01386535,  0.02980274,  0.3140843 ,
#          0.28515061],
#        [ 0.03532397, -0.04162308,  0.58879093, -0.13818821, -0.07677566,
#         -0.00296578],
#        [ 0.08136013, -0.12182411,  0.73784002, -0.01226394, -0.039509  ,
#          0.03829778],
#        [ 0.01570423, -0.07702098,  0.60828069,  0.05544249,  0.04390094,
#         -0.10427803],
#        [ 0.02590742,  0.02055364, -0.6717314 ,  0.11655467, -0.14057209,
#          0.48014871],
#        [ 0.15325314, -0.08739505, -0.5550959 , -0.06515018, -0.00340265,
#          0.236204  ],
#        [-0.15842586, -0.68683439,  0.19816162,  0.06966017, -0.12574301,
#          0.12455047],
#        [ 0.05911058, -0.74489161,  0.07703538,  0.02337389, -0.02371306,
#          0.07574639],
#        [ 0.00125791,  0.5601427 , -0.02748671, -0.17823471, -0.01578618,
#          0.34774204],
#        [-0.07727977,  0.64952601, -0.0323518 ,  0.16443032,  0.07830793,
#          0.21173981],
#        [ 0.16538321,  0.52296773,  0.23035904, -0.14658047, -0.01935456,
#         -0.01361085],
#        [ 0.89994643,  0.23899832,  0.02024251,  0.07282569, -0.11491242,
#         -0.10682055],
#        [ 0.90100743,  0.19479664,  0.03745754, -0.01281566, -0.05536655,
#         -0.17410646],
#        [ 0.72635968,  0.02268458,  0.02135864,  0.01834878,  0.01584201,
#          0.06356981],
#        [ 0.46033712, -0.32285214, -0.06513512, -0.06936854,  0.04207287,
#          0.17819581],
#        [ 0.47923063, -0.12927844,  0.03827079,  0.17869379,  0.10895296,
#          0.10401653],
#        [-0.06901997,  0.17440313,  0.06987353, -0.44476338, -0.11068822,
#          0.24731223],
#        [ 0.12158073,  0.01653794, -0.05605342,  0.51340446,  0.01308191,
#          0.13795655],
#        [-0.01277916,  0.29958804, -0.02175511, -0.53508607, -0.04770675,
#          0.27480083],
#        [ 0.11177416, -0.22575648, -0.00846031, -0.34151318,  0.12555892,
#          0.18996743],
#        [ 0.01155266, -0.00543461,  0.00350948,  0.59692033, -0.12714916,
#          0.12915488]])

# %%
personality_loadings  = pd.DataFrame(data=personality_loadings)

# %%
personality_loadings_new = personality_loadings.applymap(lambda x: np.where(x < .4, ' ', round(x,2))) 
personality_loadings_new
# Out:
#        0     1     2     3     4     5
# 0
# 1                           0.64
# 2                           0.49
# 3
# 4
# 5               0.59
# 6               0.74
# 7               0.61
# 8                                 0.48
# 9
# 10
# 11
# 12        0.56
# 13        0.65
# 14        0.52
# 15   0.9
# 16   0.9
# 17  0.73
# 18  0.46
# 19  0.48
# 20
# 21                    0.51
# 22
# 23
# 24                     0.6

# %%
personality_scores = personality_factor.transform(personality_df)

# %%
personality_scores  = pd.DataFrame(data =personality_scores )

# %%
for colnames, serie in personality_scores.iteritems():
    df[str(colnames)] = serie

# %%
df.head()
# Out:
#      A1   A2   A3   A4   A5   C1   C2   C3   C4   C5  ...   Factor3   Factor3  \
# 5   6.0  6.0  5.0  6.0  5.0  6.0  6.0  6.0  1.0  3.0  ...  0.042770 -0.702357
# 7   4.0  3.0  1.0  5.0  1.0  3.0  2.0  4.0  2.0  4.0  ...  0.235251 -0.381872
# 10  4.0  4.0  5.0  6.0  5.0  4.0  3.0  5.0  3.0  2.0  ... -0.324332 -0.291656
# 14  4.0  5.0  2.0  2.0  1.0  5.0  5.0  5.0  2.0  2.0  ...  0.160789  0.172256
# 22  1.0  5.0  6.0  5.0  6.0  4.0  3.0  2.0  4.0  5.0  ... -1.044507  0.391253
#
#      Factor4   Factor5         0         1         2         3         4  \
# 5   0.906266  1.080599  0.993906  0.315536  0.042770 -0.702357  0.906266
# 7   0.609441 -0.380616 -1.045651  1.648925  0.235251 -0.381872  0.609441
# 10 -0.131274  1.066310  0.614552  0.989915 -0.324332 -0.291656 -0.131274
# 14  0.570451 -0.048482 -0.388209 -1.684845  0.160789  0.172256  0.570451
# 22 -1.162846 -0.213704  0.848704 -0.827370 -1.044507  0.391253 -1.162846
#
#            5
# 5   1.080599
# 7  -0.380616
# 10  1.066310
# 14 -0.048482
# 22 -0.213704
#
# [5 rows x 40 columns]

# %%
df.drop(columns = ['Factor1', 'Factor2','Factor3','Factor4','Factor5' ], inplace=True)

# %%
df.rename(columns = {'0':'Factor1','1':'Factor2','2':'Factor3','3':'Factor4', '4':'Factor5','5':'Factor6' }, inplace=True)

# %%
df['gender'] = df['gender'].replace([1, 2], [1, 0])

# %%
for i in df.loc[:, 'Factor1':'Factor6']: 
    print(i)
    print(smf.ols(i + "~ gender + education + age", df).fit().summary().tables[1])
# Out:
# Factor1
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0076      0.085      0.089      0.929      -0.159       0.174
# gender        -0.0135      0.048     -0.282      0.778      -0.107       0.080
# education     -0.0188      0.021     -0.907      0.364      -0.060       0.022
# age            0.0016      0.002      0.747      0.455      -0.003       0.006
# ==============================================================================
# Factor2
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0317      0.083      0.384      0.701      -0.130       0.194
# gender        -0.0158      0.047     -0.339      0.735      -0.107       0.076
# education     -0.0067      0.020     -0.331      0.740      -0.046       0.033
# age            0.0004      0.002      0.213      0.832      -0.004       0.005
# ==============================================================================
# Factor3
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0232      0.079      0.293      0.769      -0.132       0.179
# gender        -0.0207      0.045     -0.464      0.643      -0.108       0.067
# education     -0.0049      0.019     -0.253      0.800      -0.043       0.033
# age            0.0003      0.002      0.140      0.889      -0.004       0.004
# ==============================================================================
# Factor4
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.0853      0.074     -1.148      0.251      -0.231       0.060
# gender         0.0197      0.042      0.469      0.639      -0.063       0.102
# education      0.0191      0.018      1.047      0.295      -0.017       0.055
# age            0.0008      0.002      0.450      0.653      -0.003       0.005
# ==============================================================================
# Factor5
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.0404      0.076     -0.531      0.595      -0.189       0.109
# gender        -0.0146      0.043     -0.340      0.734      -0.099       0.069
# education      0.0167      0.019      0.894      0.371      -0.020       0.053
# age         5.003e-05      0.002      0.026      0.979      -0.004       0.004
# ==============================================================================
# Factor6
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.0733      0.071     -1.028      0.304      -0.213       0.067
# gender         0.0696      0.040      1.732      0.083      -0.009       0.148
# education      0.0030      0.017      0.171      0.865      -0.031       0.037
# age            0.0014      0.002      0.801      0.423      -0.002       0.005
# ==============================================================================
