# %%
import numpy as np

# %%
df_1 = np.linspace(1,50)

# %%
df_2 = np.linspace(50, 150, num = 101)

# %%
for i in df_1:
    if (i + 1) % 2:
        print(int(i), 'es par')
    else:
        print(int(i), 'es impar')
# Out:
# 1 es impar
# 2 es par
# 3 es impar
# 4 es par
# 5 es impar
# 6 es par
# 7 es impar
# 8 es par
# 9 es impar
# 10 es par
# 11 es impar
# 12 es par
# 13 es impar
# 14 es par
# 15 es impar
# 16 es par
# 17 es impar
# 18 es par
# 19 es impar
# 20 es par
# 21 es impar
# 22 es par
# 23 es impar
# 24 es par
# 25 es impar
# 26 es par
# 27 es impar
# 28 es par
# 29 es impar
# 30 es par
# 31 es impar
# 32 es par
# 33 es impar
# 34 es par
# 35 es impar
# 36 es par
# 37 es impar
# 38 es par
# 39 es impar
# 40 es par
# 41 es impar
# 42 es par
# 43 es impar
# 44 es par
# 45 es impar
# 46 es par
# 47 es impar
# 48 es par
# 49 es impar
# 50 es par

# %%
for i in df_2:
    if ((i % 2) == 0) or ((i % 3) == 0):
        print(int(i), "es divisible por 2 o por 3")
    else: 
        print(int(i), "no")
# Out:
# 50 es divisible por 2 o por 3
# 51 es divisible por 2 o por 3
# 52 es divisible por 2 o por 3
# 53 no
# 54 es divisible por 2 o por 3
# 55 no
# 56 es divisible por 2 o por 3
# 57 es divisible por 2 o por 3
# 58 es divisible por 2 o por 3
# 59 no
# 60 es divisible por 2 o por 3
# 61 no
# 62 es divisible por 2 o por 3
# 63 es divisible por 2 o por 3
# 64 es divisible por 2 o por 3
# 65 no
# 66 es divisible por 2 o por 3
# 67 no
# 68 es divisible por 2 o por 3
# 69 es divisible por 2 o por 3
# 70 es divisible por 2 o por 3
# 71 no
# 72 es divisible por 2 o por 3
# 73 no
# 74 es divisible por 2 o por 3
# 75 es divisible por 2 o por 3
# 76 es divisible por 2 o por 3
# 77 no
# 78 es divisible por 2 o por 3
# 79 no
# 80 es divisible por 2 o por 3
# 81 es divisible por 2 o por 3
# 82 es divisible por 2 o por 3
# 83 no
# 84 es divisible por 2 o por 3
# 85 no
# 86 es divisible por 2 o por 3
# 87 es divisible por 2 o por 3
# 88 es divisible por 2 o por 3
# 89 no
# 90 es divisible por 2 o por 3
# ...

# %%
for i in df_2:
    if ((i % 2) == 0) and ((i % 3) == 0):
        print(int(i), "es divisible por 2 y por 3")
    else: 
        print(int(i), "no")
# Out:
# 50 no
# 51 no
# 52 no
# 53 no
# 54 es divisible por 2 y por 3
# 55 no
# 56 no
# 57 no
# 58 no
# 59 no
# 60 es divisible por 2 y por 3
# 61 no
# 62 no
# 63 no
# 64 no
# 65 no
# 66 es divisible por 2 y por 3
# 67 no
# 68 no
# 69 no
# 70 no
# 71 no
# 72 es divisible por 2 y por 3
# 73 no
# 74 no
# 75 no
# 76 no
# 77 no
# 78 es divisible por 2 y por 3
# 79 no
# 80 no
# 81 no
# 82 no
# 83 no
# 84 es divisible por 2 y por 3
# 85 no
# 86 no
# 87 no
# 88 no
# 89 no
# 90 es divisible por 2 y por 3
# 91 no
# 92 no
# 93 no
# 94 no
# 95 no
# 96 es divisible por 2 y por 3
# 97 no
# 98 no
# 99 no
# 100 no
# 101 no
# 102 es divisible por 2 y por 3
# 103 no
# 104 no
# 105 no
# 106 no
# 107 no
# 108 es divisible por 2 y por 3
# 109 no
# 110 no
# 111 no
# 112 no
# 113 no
# 114 es divisible por 2 y por 3
# 115 no
# 116 no
# 117 no
# 118 no
# 119 no
# 120 es divisible por 2 y por 3
# 121 no
# 122 no
# 123 no
# 124 no
# 125 no
# 126 es divisible por 2 y por 3
# 127 no
# 128 no
# 129 no
# 130 no
# 131 no
# ...

# %%
for i in df_2:
    if ((i % 2) != 0) and ((i % 3) == 0):
        print(int(i), "es divisible por 3 pero no por 2")
    else: 
        print(int(i), "no")
# Out:
# 50 no
# 51 es divisible por 3 pero no por 2
# 52 no
# 53 no
# 54 no
# 55 no
# 56 no
# 57 es divisible por 3 pero no por 2
# 58 no
# 59 no
# 60 no
# 61 no
# 62 no
# 63 es divisible por 3 pero no por 2
# 64 no
# 65 no
# 66 no
# 67 no
# 68 no
# 69 es divisible por 3 pero no por 2
# 70 no
# 71 no
# 72 no
# 73 no
# 74 no
# 75 es divisible por 3 pero no por 2
# 76 no
# 77 no
# 78 no
# 79 no
# 80 no
# 81 es divisible por 3 pero no por 2
# 82 no
# 83 no
# 84 no
# 85 no
# 86 no
# 87 es divisible por 3 pero no por 2
# 88 no
# 89 no
# 90 no
# 91 no
# 92 no
# 93 es divisible por 3 pero no por 2
# 94 no
# 95 no
# 96 no
# 97 no
# 98 no
# 99 es divisible por 3 pero no por 2
# 100 no
# 101 no
# 102 no
# 103 no
# 104 no
# 105 es divisible por 3 pero no por 2
# 106 no
# 107 no
# 108 no
# 109 no
# 110 no
# 111 es divisible por 3 pero no por 2
# 112 no
# 113 no
# 114 no
# 115 no
# 116 no
# 117 es divisible por 3 pero no por 2
# 118 no
# 119 no
# 120 no
# 121 no
# 122 no
# ...

# %%
for i in df_2:
    if ((i % 2) !=0) and ((i % 3)!=0):
        print(int(i), "no es divisible por 3 y no es divisible por 2")
    else: 
        print(int(i), "no")
# Out:
# 50 no
# 51 no
# 52 no
# 53 no es divisible por 3 y no es divisible por 2
# 54 no
# 55 no es divisible por 3 y no es divisible por 2
# 56 no
# 57 no
# 58 no
# 59 no es divisible por 3 y no es divisible por 2
# 60 no
# 61 no es divisible por 3 y no es divisible por 2
# 62 no
# 63 no
# 64 no
# 65 no es divisible por 3 y no es divisible por 2
# 66 no
# 67 no es divisible por 3 y no es divisible por 2
# 68 no
# 69 no
# 70 no
# 71 no es divisible por 3 y no es divisible por 2
# 72 no
# 73 no es divisible por 3 y no es divisible por 2
# 74 no
# 75 no
# 76 no
# 77 no es divisible por 3 y no es divisible por 2
# 78 no
# 79 no es divisible por 3 y no es divisible por 2
# 80 no
# 81 no
# 82 no
# 83 no es divisible por 3 y no es divisible por 2
# 84 no
# 85 no es divisible por 3 y no es divisible por 2
# 86 no
# 87 no
# 88 no
# 89 no es divisible por 3 y no es divisible por 2
# 90 no
# 91 no es divisible por 3 y no es divisible por 2
# 92 no
# 93 no
# 94 no
# ...

# %%
#Xorreccion errores
'''for i in range(100):
    print(I**2) la I no debe ser mayuscula'''

for i in range(100):
    print(i**2)
# Out:
# 0
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81
# 100
# 121
# 144
# 169
# 196
# 225
# 256
# 289
# 324
# 361
# 400
# 441
# 484
# 529
# 576
# 625
# 676
# 729
# 784
# 841
# 900
# 961
# 1024
# 1089
# 1156
# 1225
# 1296
# 1369
# 1444
# 1521
# 1600
# 1681
# 1764
# 1849
# 1936
# 2025
# 2116
# 2209
# 2304
# 2401
# 2500
# 2601
# 2704
# 2809
# 2916
# 3025
# 3136
# 3249
# 3364
# 3481
# 3600
# 3721
# 3844
# 3969
# 4096
# 4225
# 4356
# 4489
# 4624
# 4761
# 4900
# 5041
# 5184
# 5329
# 5476
# 5625
# 5776
# 5929
# 6084
# 6241
# 6400
# 6561
# 6724
# 6889
# 7056
# 7225
# 7396
# 7569
# 7744
# 7921
# 8100
# 8281
# 8464
# 8649
# 8836
# 9025
# 9216
# 9409
# 9604
# 9801

# %%
'''Desafío 5
Utilizando la misma base flights.csv hacer un loop y clasificar los meses con una
cantidad de pasajeros menor a la media
Para ello, generen un nuevo objeto que represente la media de passengers .
Generen una columna en la base de datos que se llame underperforming y asígnele 0.
Ejecuten un loop que recorra cada observación de passengers , donde si la observación es
menor a la media de passengers se le asigne a underperforming un 1.
Para asignar unos en la columna underperforming ya creada, utilice la función
set_value .'''
import pandas as pd
df = pd.read_csv ("flights.csv")
df
# Out:
#      year      month  passengers
# 0    1949    January         112
# 1    1949   February         118
# 2    1949      March         132
# 3    1949      April         129
# 4    1949        May         121
# ..    ...        ...         ...
# 139  1960     August         606
# 140  1960  September         508
# 141  1960    October         461
# 142  1960   November         390
# 143  1960   December         432
#
# [144 rows x 3 columns]

# %%
pasajeros = df["passengers"]
media = np.mean(pasajeros)
media
# Out:
# 280.2986111111111

# %%
df["underperforming"] = 0

# %%
df
# Out:
#      year      month  passengers  underperforming
# 0    1949    January         112                0
# 1    1949   February         118                0
# 2    1949      March         132                0
# 3    1949      April         129                0
# 4    1949        May         121                0
# ..    ...        ...         ...              ...
# 139  1960     August         606                0
# 140  1960  September         508                0
# 141  1960    October         461                0
# 142  1960   November         390                0
# 143  1960   December         432                0
#
# [144 rows x 4 columns]

# %%
for rowname, rowseries in df.iterrows():
    if rowseries['passengers'] < media:
        rowseries['underperforming'] == 1

# %%
df
# Out:
#      year      month  passengers  underperforming
# 0    1949    January         112                0
# 1    1949   February         118                0
# 2    1949      March         132                0
# 3    1949      April         129                0
# 4    1949        May         121                0
# ..    ...        ...         ...              ...
# 139  1960     August         606                0
# 140  1960  September         508                0
# 141  1960    October         461                0
# 142  1960   November         390                0
# 143  1960   December         432                0
#
# [144 rows x 4 columns]

# %%
'''Desafío 6
Hacer un loop que clasifique los meses donde la cantidad de pasajeros se escapa de la tendencia.
Para ello, genere dos objetos que guarden la media general y la desviación estandar general
de passengers .
Genere una nueva columna en la tabla de datos que se llame outlier y asignele 0.
Ejecuten un loop que recorra cada observación de passengers , donde si la observación se
escapa de la tendencia sea 1, de lo contrario 0.
Para clasificar los casos que se escapen la tendencia, la observación debe satisfacer una de
las siguientes condiciones:
La observación debe ser menor a la media menos la desviación estándar, o
La observación debe ser mayor a la media más la desviación estándar.
¿Cuántas observaciones se pueden clasificar como casos extremos'''

desviacion_pasajeros = np.std(pasajeros)

# %%
for rowname, rowserie in df.iterrows():
    if rowserie["passengers"] < media:
        df["outlier"] = 1

# %%
df
# Out:
#      year      month  passengers  underperforming  outlier
# 0    1949    January         112                0        1
# 1    1949   February         118                0        1
# 2    1949      March         132                0        1
# 3    1949      April         129                0        1
# 4    1949        May         121                0        1
# ..    ...        ...         ...              ...      ...
# 139  1960     August         606                0        1
# 140  1960  September         508                0        1
# 141  1960    October         461                0        1
# 142  1960   November         390                0        1
# 143  1960   December         432                0        1
#
# [144 rows x 5 columns]

# %%
pasajeros= df["passengers"]
media_general = np.mean(pasajeros)
desviacion_general=np.std(pasajeros)
print(media_general)
print(desviacion_general)
# Out:
# 280.2986111111111
# 119.54904153277147

# %%
df["outlier"]=0
df
# Out:
#      year      month  passengers  underperforming  outlier
# 0    1949    January         112                0        0
# 1    1949   February         118                0        0
# 2    1949      March         132                0        0
# 3    1949      April         129                0        0
# 4    1949        May         121                0        0
# ..    ...        ...         ...              ...      ...
# 139  1960     August         606                0        0
# 140  1960  September         508                0        0
# 141  1960    October         461                0        0
# 142  1960   November         390                0        0
# 143  1960   December         432                0        0
#
# [144 rows x 5 columns]

# %%
minimo=media_general-desviacion_general
maximo=media_general+desviacion_general
print(minimo)
print(maximo)
# Out:
# 160.74956957833962
# 399.84765264388255

# %%
for rowname, rowserie in df.iterrows():
    if (rowserie["passengers"] < inimo) or (rowserie["passengers"] > maximo):
        df["outlier"] = 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\dmard\Documents\GitHub\Fundamentos data sciens\desafios\desafio 2\desafio_2.ipynb Celda 22 in <cell line: 1>()
#       <a href='vscode-notebook-cell:/c%3A/Users/dmard/Documents/GitHub/Fundamentos%20data%20sciens/desafios/desafio%202/desafio_2.ipynb#X34sZmlsZQ%3D%3D?line=0'>1</a> for rowname, rowserie in df.iterrows():
# ----> <a href='vscode-notebook-cell:/c%3A/Users/dmard/Documents/GitHub/Fundamentos%20data%20sciens/desafios/desafio%202/desafio_2.ipynb#X34sZmlsZQ%3D%3D?line=1'>2</a>     if (rowserie["passengers"] < inimo) or (rowserie["passengers"] > maximo):
#       <a href='vscode-notebook-cell:/c%3A/Users/dmard/Documents/GitHub/Fundamentos%20data%20sciens/desafios/desafio%202/desafio_2.ipynb#X34sZmlsZQ%3D%3D?line=2'>3</a>         df["outlier"] = 1
#
# NameError: name 'inimo' is not defined

# %%
df
# Out:
#      year      month  passengers  underperforming  outlier
# 0    1949    January         112                1        1
# 1    1949   February         118                1        1
# 2    1949      March         132                1        1
# 3    1949      April         129                1        1
# 4    1949        May         121                1        1
# ..    ...        ...         ...              ...      ...
# 139  1960     August         606                1        1
# 140  1960  September         508                1        1
# 141  1960    October         461                1        1
# 142  1960   November         390                1        1
# 143  1960   December         432                1        1
#
# [144 rows x 5 columns]

# %%
df.loc[df.outlier == 1, 'outlier'].count()
# Out:
# 144

# %%
print("Se pueden clasificar", df.loc[df.outlier == 1, 'outlier'].count(), "observaciones como casos extremos.")
# Out:
# Se pueden clasificar 144 observaciones como casos extremos.
