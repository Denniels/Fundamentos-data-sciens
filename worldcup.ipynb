# %%
#● Importa pandas y numpy siguiendo las convenciones.
import pandas as pd
import numpy as np

# %%
#● Lee la base de datos worldcup2014.csv y asígnela a un objeto df.
df = pd.read_csv('datasets/worldcup2014.csv')

# %%
#● Solicita las primeras 5 observaciones con head.
df.head(5)
# Out:
#           team     continent group  group_pos  cantidad_juegos  \
# 0       Brazil  southamerica     A          1                3
# 1       Mexico  northamerica     A          2                3
# 2      Croatia        europe     A          3                3
# 3     Cameroon        africa     A          4                3
# 4  Netherlands        europe     B          1                3
#
#    juegos_ganados  juegos_empatados  juegos_perdidos  goles_favor  \
# 0               2                 1                0            7
# 1               2                 1                0            4
# 2               1                 0                2            6
# 3               0                 0                3            1
# 4               3                 0                0           10
#
#    goles_contra goles_diferencia  puntos  clasificado
# 0             2                5       7            1
# 1             1                3       7            1
# 2             6                0       3            0
# 3             9               −8       0            0
# 4             3                7       9            1

# %%
#● Solicita las ultimas 5 observaciones con tail.
df.tail(5)
# Out:
#            team continent group  group_pos  cantidad_juegos  juegos_ganados  \
# 27        Ghana    africa     G          4                3               0
# 28      Belgium    europe     H          1                3               3
# 29      Algeria    africa     H          2                3               1
# 30       Russia    europe     H          3                3               0
# 31  South Korea      asia     H          4                3               0
#
#     juegos_empatados  juegos_perdidos  goles_favor  goles_contra  \
# 27                 1                2            4             6
# 28                 0                0            4             1
# 29                 1                1            6             5
# 30                 2                1            2             3
# 31                 1                2            3             6
#
#    goles_diferencia  puntos  clasificado
# 27               −2       1            0
# 28                3       9            1
# 29                1       4            1
# 30               −1       2            0
# 31               −3       1            0

# %%
'''
Frecuencia de continent: utilizando value_counts responde lo siguiente:
● ¿Cuál es el continente con una mayor presencia en la muestra?
● ¿Cuál es la probabilidad de elegir un equipo asiático al azar?
● ¿Cuál es la probabilidad de elegir un equipo africano al azar?
'''
continente_mayor_frecuiencia = df['continent'].value_counts()
continente_mayor_frecuiencia
# Out:
# europe          13
# southamerica     6
# africa           5
# northamerica     4
# asia             4
# Name: continent, dtype: int64

# %%
continente_mayor_frecuiencia = df['continent'].value_counts('%')
continente_mayor_frecuiencia
# Out:
# europe          0.40625
# southamerica    0.18750
# africa          0.15625
# northamerica    0.12500
# asia            0.12500
# Name: continent, dtype: float64

# %%
continente_mayor_frecuiencia = df['continent'].value_counts(normalize = True)
continente_mayor_frecuiencia
# Out:
# europe          0.40625
# southamerica    0.18750
# africa          0.15625
# northamerica    0.12500
# asia            0.12500
# Name: continent, dtype: float64

# %%
df.loc[:, ['continent', 'clasificado']].head(30)
# Out:
#        continent  clasificado
# 0   southamerica            1
# 1   northamerica            1
# 2         europe            0
# 3         africa            0
# 4         europe            1
# 5   southamerica            1
# 6         europe            0
# 7           asia            0
# 8   southamerica            1
# 9         europe            1
# 10        africa            0
# 11          asia            0
# 12  northamerica            1
# 13  southamerica            1
# 14        europe            0
# 15        europe            0
# 16        europe            1
# 17        europe            1
# 18  southamerica            0
# 19  northamerica            0
# 20  southamerica            1
# 21        africa            1
# 22        europe            0
# 23          asia            0
# 24        europe            1
# 25  northamerica            1
# 26        europe            0
# 27        africa            0
# 28        europe            1
# 29        africa            1

# %%
#● ¿Cuál es la probabilidad de elegir un equipo asiático al azar?
escoje_asia = 0
for rowname, rowserie in df.iterrows():
    if rowserie['continent'] == 'asia' and rowserie['clasificado'] == 1.0:
        print(rowserie['team'])
        escoje_asia += 1
print(escoje_asia)
# Out:
# 0

# %%
len(df)
# Out:
# 32

# %%
escoje_asia / len(df)
# Out:
# 0.0

# %%
df['escoje_asia'] = np.logical_and(df['continent'] == 'asia',
                                df['clasificado'] == 1.0)

# %%
#● ¿Cuál es la probabilidad de elegir un equipo asiático al azar?
# ningun equipo asiatico clasifico en la muestra por lo que hay una probabilidad del 100% de que no se escoja un equipo asiatico
df['escoje_asia'].value_counts('%')
# Out:
# False    1.0
# Name: escoje_asia, dtype: float64

# %%
#● ¿Cuál es la probabilidad de elegir un equipo africano al azar?
escoje_africa = 0
for rowname, rowserie in df.iterrows():
    if rowserie['continent'] == 'africa' and rowserie['clasificado'] == 1.0:
        print(rowserie['team'])
        escoje_africa	 += 1

print(escoje_africa)
# Out:
# Nigeria
# Algeria
# 2

# %%
len(df)
# Out:
# 32

# %%
escoje_africa / len(df)
# Out:
# 0.0625

# %%
df['escoje_africa'] = np.logical_and(df['continent'] == 'africa',
                                df['clasificado'] == 1.0)

# %%
#● ¿Cuál es la probabilidad de elegir un equipo africano al azar?
#solo dos paises africanos tubieron clasiificacion, por lo que hay una probabilidad de casi un 93% de no escojer a uno de estos equipos
df['escoje_africa'].value_counts('%')
# Out:
# False    0.9375
# True     0.0625
# Name: escoje_africa, dtype: float64

# %%
df
# Out:
#                       team     continent group  group_pos  cantidad_juegos  \
# 0                   Brazil  southamerica     A          1                3
# 1                   Mexico  northamerica     A          2                3
# 2                  Croatia        europe     A          3                3
# 3                 Cameroon        africa     A          4                3
# 4              Netherlands        europe     B          1                3
# 5                    Chile  southamerica     B          2                3
# 6                    Spain        europe     B          3                3
# 7                Australia          asia     B          4                3
# 8                 Colombia  southamerica     C          1                3
# 9                   Greece        europe     C          2                3
# 10             Ivory Coast        africa     C          3                3
# 11                   Japan          asia     C          4                3
# 12              Costa Rica  northamerica     D          1                3
# 13                 Uruguay  southamerica     D          2                3
# 14                   Italy        europe     D          3                3
# 15                 England        europe     D          4                3
# 16                  France        europe     E          1                3
# 17             Switzerland        europe     E          2                3
# 18                 Ecuador  southamerica     E          3                3
# 19                Honduras  northamerica     E          4                3
# 20               Argentina  southamerica     F          1                3
# 21                 Nigeria        africa     F          2                3
# 22  Bosnia and Herzegovina        europe     F          3                3
# 23                    Iran          asia     F          4                3
# 24                 Germany        europe     G          1                3
# 25           United States  northamerica     G          2                3
# 26                Portugal        europe     G          3                3
# 27                   Ghana        africa     G          4                3
# 28                 Belgium        europe     H          1                3
# 29                 Algeria        africa     H          2                3
# 30                  Russia        europe     H          3                3
# 31             South Korea          asia     H          4                3
#
#     juegos_ganados  juegos_empatados  juegos_perdidos  goles_favor  \
# 0                2                 1                0            7
# 1                2                 1                0            4
# 2                1                 0                2            6
# 3                0                 0                3            1
# 4                3                 0                0           10
# 5                2                 0                1            5
# 6                1                 0                2            4
# 7                0                 0                3            3
# 8                3                 0                0            9
# 9                1                 1                1            2
# 10               1                 0                2            4
# 11               0                 1                2            2
# 12               2                 1                0            4
# 13               2                 0                1            4
# 14               1                 0                2            2
# 15               0                 1                2            2
# 16               2                 1                0            8
# 17               2                 0                1            7
# 18               1                 1                1            3
# 19               0                 0                3            1
# 20               3                 0                0            6
# 21               1                 1                1            3
# 22               1                 0                2            4
# 23               0                 1                2            1
# 24               2                 1                0            7
# 25               1                 1                1            4
# 26               1                 1                1            4
# 27               0                 1                2            4
# 28               3                 0                0            4
# 29               1                 1                1            6
# 30               0                 2                1            2
# 31               0                 1                2            3
#
#     goles_contra goles_diferencia  puntos  clasificado  escoje_asia  \
# 0              2                5       7            1        False
# 1              1                3       7            1        False
# 2              6                0       3            0        False
# 3              9               −8       0            0        False
# 4              3                7       9            1        False
# 5              3                2       6            1        False
# 6              7               −3       3            0        False
# 7              9               −6       0            0        False
# 8              2                7       9            1        False
# 9              4               −2       4            1        False
# 10             5               −1       3            0        False
# 11             6               −4       1            0        False
# 12             1                3       7            1        False
# 13             4                0       6            1        False
# 14             3               −1       3            0        False
# 15             4               −2       1            0        False
# 16             2                6       7            1        False
# 17             6                1       6            1        False
# 18             3                0       4            0        False
# 19             8               −7       0            0        False
# 20             3                3       9            1        False
# 21             3                0       4            1        False
# 22             4                0       3            0        False
# 23             4               −3       1            0        False
# 24             2                5       7            1        False
# 25             4                0       4            1        False
# 26             7               −3       4            0        False
# 27             6               −2       1            0        False
# 28             1                3       9            1        False
# 29             5                1       4            1        False
# 30             3               −1       2            0        False
# 31             6               −3       1            0        False
#
#     escoje_africa
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
# 5           False
# 6           False
# 7           False
# 8           False
# 9           False
# 10          False
# 11          False
# 12          False
# 13          False
# 14          False
# 15          False
# 16          False
# 17          False
# 18          False
# 19          False
# 20          False
# 21           True
# 22          False
# 23          False
# 24          False
# 25          False
# 26          False
# 27          False
# 28          False
# 29           True
# 30          False
# 31          False
