# %% [markdown]
# <h1 align="center" style="background-color:DodgerBlue;">Prueba - Hito 1</h1>
#
# * Para realizar esta prueba debes haber estudiado previamente todo el material disponible correspondiente al módulo.
# * Una vez terminada la prueba, comprime la carpeta que contiene el desarrollo de los requerimientos solicitados y sube el .zip en el LMS.
# * Puntaje total: 5 puntos.
# * Desarrollo prueba:
#   * La prueba se debe desarrollar de manera Individual.
#
# ### Objetivo
#
# Completar el punto de Preliminares, así como Aspectos computacionales.
#
# * Elementos a considerar en éste hito:
#
#   * Los dos enunciados deben estar claros, considerando el tipo de problema a
# resolver (regresión o clasificación). Para cada uno de los enunciados y su
# problema identificado, se debe justificar el uso de métricas para medir el
# desempeño del problema. (6 Puntos)
#
#   * Se debe considerar el uso de las librerías asociadas para la ingesta,
# preprocesamiento, visualización y modelación, así como métricas de
# evaluación. (2 Puntos)
#
#   * Se debe detallar y considerar el proceso de preprocesamiento y
# recodificación de datos. (2 Puntos)
#
# * Entregable: Dos notebooks (uno por enunciado) con todos los puntos detallados.
#
# ### Desafío 2: Rendimiento escolar
#
# Lo contactan de una escuela Portuguesa para generar un modelo que identifique aquellos
# alumnos que presentan un bajo desempeño académico, medido en el promedio final del año
# escolar. Para ello le envían un archivo con registros sociodemográficos y conductuales de
# los alumnos de dos escuelas para perfilar a los estudiantes.
#
# De manera adicional la psicopedagoga sugiere inspeccionar una batería de preguntas
# asociadas a aspectos ambientales del alumno (de famrel a health) y ver si éstas se
# pueden abstraer en categorías latentes.
#
# ### Descripción de la base de datos
#
# Para responder esta pregunta deben utilizar el archivo students.csv.
#
# Las variables que componen la base se detallan a continuación.
#
# * school: Escuela del estudiante. (binaria: 'GP' - Gabriel Pereira o 'MS' - Mousinho da Silveira).
# * sex: Sexo del estudiante. (binaria: 'F' - Mujer o 'M' - Hombre).
# * age: Edad del estudiante. (numérica: de 15 a 22).
# * address: Ubicación de la casa del estudiante. (binaria: 'U' - urbana o 'R' - rural).
# * famsize: Tamaño de la familia. (binaria: 'LE3' - less or equal to 3 or 'GT3' - greater than 3).
# * Pstatus: Estado cohabitacional de los padres. (binaria: 'T' - cohabitando juntos o 'A' - viviendo separados).
# * Medu: Nivel educacional de la madre. (numérica: 0 - ninguno, 1 - educación básica (4to), 2 - de 5to a 9, 3 - educación media, o 4 - educación superior).
# * Fedu: Nivel educacional del padre. (numérica: 0 - ninguno, 1 - educación básica (4to), 2 - de 5to a 9, 3 - educación media, o 4 - educación superior).
# * Mjob: Ocupación de la madre. (nominal: 'teacher' profesora, 'health' relacionada a salud, 'services' (e.g. administración pública o policía), 'at_home' en casa u 'other' otra).
# * job:: Ocupación del padre (nominal: 'teacher' profesor, 'health' relacionado a salud, 'services' (e.g. administración pública o policía), 'at_home' en casa u 'other' otra).
# * reason: Razón para escoger la escuela (nominal: 'home' cercano a casa, 'reputation' reputación de la escuela, 'course' preferencia de cursos u 'other' otra).
# * guardian: Apoderado del estudiante (nominal: 'mother' madre, 'father' padre u 'other' otro).
#
# * traveltime: Tiempo de viaje entre hogar y colegio. Se debe codificar como:
#   * 1 si es menos de 15 min,
#   * 2 si es de 15 a 30 min,
#   * 3 si es de 30 min. a 1 hora,
#   * 4 - si es más de 1 hora).
#
# * studytime: Horas semanales dedicadas al estudio. Se debe codificar como:
#   * 1 si es menos de 2 horas,
#   * 2 si es de 2 a 5 horas,
#   * 3 si es de 5 a 10 horas,
#   * 4 si es más de 10 horas.
#
# * failures: Número de clases reprobadas. (numérica: n si 1<=n<3, de lo contrario 4).
# * schoolsup: Apoyo educacional del colegio. (binaria: si o no).
# * famsup: Apoyo educacional familiar. (binaria: si o no).
# * paid: Clases particulares pagadas (matemáticas o portugués) (binaria: sí o no).
# * activities: Actividades extracurriculares. (binaria: si o no).
# * nursery: Asistió a guardería infantil. (binaria: si o no).
# * higher: Desea proseguir estudios superiores (binaria: si o no).
# * internet: Acceso a internet desde el hogar (binaria: si o no).
# * romantic: Relación romántica (binaria: si o no).
# * famrel: Calidad de las relaciones familiares. (numérica: de 1 - muy malas a 5 - excelentes).
# * freetime: Tiempo libre fuera del colegio (numérica: de 1 - muy poco a 5 - mucho).
# * goout: Salidas con amigos (numérica: de 1 - muy pocas a 5 - muchas).
# * Dalc: Consumo de alcohol en día de semana (numérica: de 1 - muy bajo a 5 - muy alto).
# * Walc: Consumo de alcohol en fines de semana (numérica: de 1 - muy bajo a 5 - muy alto).
# * health: Estado de salud actual (numérica: from 1 - muy malo to 5 - muy bueno).
# * absences: Cantidad de ausencias escolares (numérica: de 0 a 93).
# * G1: Notas durante el primer semestre (numérica: de 0 a 20). Este es uno de sus vectores objetivos para el modelo descriptivo.
# * G2: Notas durante el segundo semestre (numérica: de 0 a 20). Este es uno de sus vectores objetivos para el modelo descriptivo.
# * G3: Promedio final (numérica: de 0 a 20). Este es uno de sus vectores objetivos para
# el modelo descriptivo y el vector a predecir en el modelo predictivo.
#
# ### Aspectos adicionales a considerar
#
# * La base de datos presenta una serie de anomalías. En la escuela no tienen buenas
# prácticas sobre cómo ingresar datos, por lo que existen datos perdidos que están
# registrados bajo tres categorías: nulidade, sem validade, zero. De manera adicional,
# hay 3 variables numéricas que se registraron como strings, cuya interpretación en
# pandas devuelve una estructura de datos genérica. Finalmente, la base está con un
# encoding distinto al normal y los delimitadores son distintos.
#
# * Para simplificar el análisis y su posterior inclusión en un modelo predictivo, se
# sugiere recodificar las variables binarias como 0 y 1. Se recomienda seguir el criterio
# de asignarle 1 a aquellas categorías minoritarias.
#
# * El procedimiento también debe aplicarse para aquellas variables nominales con más
# de 2 categorías siguiendo la misma lógica.
#
# * En la parte de modelación descriptiva, se deben generar modelos utilizando todos
# los predictores por cada una de las notas registradas en G1, G2 y G3.
#
# * Para la parte de modelación predictiva, se debe generar un modelo para predecir las
# notas en G3.

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import scipy.stats as stats
import statsmodels.formula.api as smf
import argparse
import os
import time
import func as gfx

# machine learning libraries
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.metrics import roc_curve, classification_report 

import factor_analyzer as factor

from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()

plt.style.use('seaborn')
plt.rcParams["figure.figsize"] = (8, 6)
plt.rcParams["figure.dpi"] = 70
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('students.csv', sep = '|', encoding='latin-1').drop('Unnamed: 0', axis = 1)
df.head()
# Out:
#   school sex           age address famsize Pstatus Medu Fedu     Mjob  \
# 0     GP   F      nulidade       U     GT3       A    4    4  at_home
# 1     GP   F          "17"       U     GT3       T    1    1  at_home
# 2     GP   F          "15"       U     LE3       T    1    1  at_home
# 3     GP   F          "15"       U     GT3       T    4    2   health
# 4     GP   F  sem validade       U     GT3       T    3    3    other
#
#        Fjob  ... famrel freetime goout Dalc Walc health absences    G1  G2  G3
# 0   teacher  ...      4        3   "4"    1    1    "3"        6     5   6   6
# 1     other  ...      5        3   "3"    1    1    "3"        4     5   5   6
# 2     other  ...      4        3   "2"    2    3    "3"       10  zero   8  10
# 3  services  ...      3        2   "2"    1    1    "5"        2    15  14  15
# 4     other  ...      4        3   "2"    1    2    "5"        4     6  10  10
#
# [5 rows x 33 columns]

# %%
# lista nulos
null_list = ['sem validade', 'zero', 'nulidade']

# %%
# transformacion incorrecto formato de variables

for col in ['age', 'goout', 'health']:
        df[col] = df[col].str.replace('"', "").replace(null_list, [np.nan, np.nan, np.nan]).astype('float')

# %%
# reemplazo de valores nulos en otras variables

for col in df.columns:
        if col not in ['age', 'goout', 'health', 'G2']:
                df[col] = df[col].replace(null_list, [np.nan, np.nan, np.nan])
        if col in ['failures', 'absences', 'G1', 'G3']:
                df[col] = df[col].astype(float)

# %%
df_summary = gfx.summary_drop(df)
df_summary
# Out:
#                tipo  nulos  porc_nulos  ceros  porc_ceros  count unique  \
# G2            int64      0    0.000000     13    0.032911  395.0    NaN
# failures    float64      5    0.012658    308    0.779747  390.0    NaN
# goout       float64      5    0.012658      0    0.000000  390.0    NaN
# health      float64      4    0.010127      0    0.000000  391.0    NaN
# G3          float64      3    0.007595     37    0.093671  392.0    NaN
# age         float64      4    0.010127      0    0.000000  391.0    NaN
# G1          float64      4    0.010127      0    0.000000  391.0    NaN
# absences    float64      4    0.010127    113    0.286076  391.0    NaN
# Walc         object      5    0.012658      0    0.000000    390      5
# Dalc         object      3    0.007595      0    0.000000    392      5
# activities   object      5    0.012658      0    0.000000    390      2
# famrel       object      5    0.012658      0    0.000000    390      5
# ...

# %%
# Visualizacion de valores nulos
df_summary['porc_nulos'].plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
# Inspección visual vector objetivo
for col in ['G1', 'G2', 'G3']:
        sns.countplot(x = df[col])
        plt.axvline(df[col].mean())
        plt.title(f'Distribución para variable: {col} - línea vertical representa la media')
        plt.show()

# %%
# relacion entre escuela y promedio final
sns.boxplot(x='school', y='G3', data=df)
plt.title('Escuela vs Promedio Final')
# Out:
# Text(0.5, 1.0, 'Escuela vs Promedio Final')

# %%
# relacion entre sexo y promedio final
sns.boxplot(x='sex', y='G3', data=df)
plt.title('Sexo vs Promedio Final')
# Out:
# Text(0.5, 1.0, 'Sexo vs Promedio Final')

# %%
# relacion entre tiempo libre y promedio final
sns.boxplot(x='freetime', y='G3', data=df)
plt.title('Tiempo libre vs Promedio Final')
# Out:
# Text(0.5, 1.0, 'Tiempo libre vs Promedio Final')

# %%
# relacion ocupación de la madre en el promedio
sns.boxplot(x='Mjob', y='G3', hue='sex', data=df)
plt.title('Ocupación de la madre vs promedio final')
# Out:
# Text(0.5, 1.0, 'Ocupación de la madre vs promedio final')

# %%
# relacion ocupación del padre vs el promedio
sns.boxplot(x='Fjob', y = 'G3', hue='sex', data=df)
plt.title('Ocupación del padre vs promedio final')
# Out:
# Text(0.5, 1.0, 'Ocupación del padre vs promedio final')

# %%
sns.boxplot(x='studytime', y='G3', hue='sex', data=df)
plt.title('Tiempo de estudio vs promedio final')
# Out:
# Text(0.5, 1.0, 'Tiempo de estudio vs promedio final')

# %%
sns.heatmap(round(df.corr(), 2), annot=True, cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <AxesSubplot:>

# %%
df.head()
# Out:
#   school sex   age address famsize Pstatus Medu Fedu     Mjob      Fjob  ...  \
# 0     GP   F   NaN       U     GT3       A    4    4  at_home   teacher  ...
# 1     GP   F  17.0       U     GT3       T    1    1  at_home     other  ...
# 2     GP   F  15.0       U     LE3       T    1    1  at_home     other  ...
# 3     GP   F  15.0       U     GT3       T    4    2   health  services  ...
# 4     GP   F   NaN       U     GT3       T    3    3    other     other  ...
#
#   famrel freetime goout Dalc  Walc health absences    G1  G2    G3
# 0      4        3   4.0    1     1    3.0      6.0   5.0   6   6.0
# 1      5        3   3.0    1     1    3.0      4.0   5.0   5   6.0
# 2      4        3   2.0    2     3    3.0     10.0   NaN   8  10.0
# 3      3        2   2.0    1     1    5.0      2.0  15.0  14  15.0
# 4      4        3   2.0    1     2    5.0      4.0   6.0  10  10.0
#
# [5 rows x 33 columns]

# %%
# Realizamos un LabelEncoder para transformar datos en datos continuos.
df['school_lb']=labelencoder.fit_transform(df['school'])
df['sex_lb']=labelencoder.fit_transform(df['sex'])
df['address_lb']=labelencoder.fit_transform(df['address'])
df['famsize_lb']=labelencoder.fit_transform(df['famsize'])
df['Pstatus_lb']=labelencoder.fit_transform(df['Pstatus'])
df['Medu_lb']=labelencoder.fit_transform(df['Medu'])
df['Fedu_lb']=labelencoder.fit_transform(df['Fedu'])
df['Mjob_lb']=labelencoder.fit_transform(df['Mjob'])
df['Fjob_lb']=labelencoder.fit_transform(df['Fjob'])
df['reason_lb']=labelencoder.fit_transform(df['reason'])
df['guardian_lb']=labelencoder.fit_transform(df['guardian'])
df['traveltime_lb']=labelencoder.fit_transform(df['traveltime'])
df['studytime_lb']=labelencoder.fit_transform(df['studytime'])
df['schoolsup_lb']=labelencoder.fit_transform(df['schoolsup'])
df['famsup_lb']=labelencoder.fit_transform(df['famsup'])
df['paid_lb']=labelencoder.fit_transform(df['paid'])
df['activities_lb']=labelencoder.fit_transform(df['activities'])
df['nursery_lb']=labelencoder.fit_transform(df['nursery'])
df['higher_lb']=labelencoder.fit_transform(df['higher'])
df['internet_lb']=labelencoder.fit_transform(df['internet'])
df['romantic_lb']=labelencoder.fit_transform(df['romantic'])
df['famrel_lb']=labelencoder.fit_transform(df['famrel'])
df['freetime_lb']=labelencoder.fit_transform(df['freetime'])
df['Dalc_lb']=labelencoder.fit_transform(df['Dalc'])
df['Walc_lb']=labelencoder.fit_transform(df['Walc'])
df.head()
# Out:
#   school sex   age address famsize Pstatus Medu Fedu     Mjob      Fjob  ...  \
# 0     GP   F   NaN       U     GT3       A    4    4  at_home   teacher  ...
# 1     GP   F  17.0       U     GT3       T    1    1  at_home     other  ...
# 2     GP   F  15.0       U     LE3       T    1    1  at_home     other  ...
# 3     GP   F  15.0       U     GT3       T    4    2   health  services  ...
# 4     GP   F   NaN       U     GT3       T    3    3    other     other  ...
#
#   paid_lb activities_lb nursery_lb higher_lb  internet_lb romantic_lb  \
# 0       0             0          1         1            0           0
# 1       0             0          0         1            1           0
# 2       1             0          1         1            1           0
# 3       1             1          1         1            1           1
# 4       1             0          1         1            0           0
#
#   famrel_lb freetime_lb Dalc_lb Walc_lb
# 0         3           2       0       0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 58 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   school         390 non-null    object
#  1   sex            392 non-null    object
#  2   age            391 non-null    float64
#  3   address        393 non-null    object
#  4   famsize        391 non-null    object
#  5   Pstatus        389 non-null    object
#  6   Medu           392 non-null    object
#  7   Fedu           390 non-null    object
#  8   Mjob           389 non-null    object
#  9   Fjob           395 non-null    object
#  10  reason         391 non-null    object
#  11  guardian       391 non-null    object
#  12  traveltime     392 non-null    object
#  13  studytime      390 non-null    object
#  14  failures       390 non-null    float64
#  15  schoolsup      387 non-null    object
#  16  famsup         390 non-null    object
# ...

# %%
# Tomamos todas las variables continuas en un dataframe limpio
df2 = df.loc[:, ['school_lb','sex_lb','address_lb','famsize_lb','Pstatus_lb','Medu_lb','Fedu_lb','Mjob_lb','Fjob_lb',
                'reason_lb','guardian_lb','traveltime_lb','studytime_lb','schoolsup_lb','famsup_lb','paid_lb',
                'activities_lb','nursery_lb','higher_lb','internet_lb','romantic_lb','famrel_lb','freetime_lb',
                'Dalc_lb','Walc_lb','age','failures','goout','health','absences','G1','G2','G3']].dropna()
df2.head()
# Out:
#    school_lb  sex_lb  address_lb  famsize_lb  Pstatus_lb  Medu_lb  Fedu_lb  \
# 1          0       0           1           0           1        1        1
# 3          0       0           1           0           1        4        2
# 5          0       1           1           1           1        4        3
# 6          0       1           1           1           1        2        2
# 7          0       0           1           0           0        4        4
#
#    Mjob_lb  Fjob_lb  reason_lb  ...  Dalc_lb  Walc_lb   age  failures  goout  \
# 1        0        2          0  ...        0        0  17.0       0.0    3.0
# 3        1        3          1  ...        0        0  15.0       0.0    2.0
# 5        3        2          3  ...        0        1  16.0       0.0    2.0
# 6        2        2          1  ...        0        0  16.0       0.0    4.0
# 7        2        4          1  ...        0        0  17.0       0.0    4.0
#
#    health  absences    G1  G2    G3
# ...

# %%
form1 = gfx.form_model(df2, var_obj = 'G1')
lineal_model1 = smf.ols(form1 ,data = df2).fit()
lineal_model1.summary2()
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                  Results: Ordinary least squares
# ...
# Model:              OLS              Adj. R-squared:     0.750
# Dependent Variable: G1               AIC:                1443.5997
# Date:               2022-09-30 21:36 BIC:                1572.4767
# No. Observations:   367              Log-Likelihood:     -688.80
# Df Model:           32               F-statistic:        35.26
# Df Residuals:       334              Prob (F-statistic): 5.67e-88
# R-squared:          0.772            Scale:              2.7457
# -------------------------------------------------------------------
#                 Coef.   Std.Err.     t     P>|t|    [0.025   0.975]
# -------------------------------------------------------------------
# Intercept       0.0235    1.6386   0.0143  0.9886  -3.1998   3.2468
# school_lb      -0.3543    0.2558  -1.3852  0.1669  -0.8574   0.1488
# sex_lb          0.0771    0.2011   0.3834  0.7017  -0.3185   0.4727
# ...

# %%
form2 = gfx.form_model(df2, var_obj = 'G2')
lineal_model2 = smf.ols(form2 ,data = df2).fit()
lineal_model2.summary2()
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                  Results: Ordinary least squares
# ...
# Model:              OLS              Adj. R-squared:     0.867
# Dependent Variable: G2               AIC:                1306.4608
# Date:               2022-09-30 21:36 BIC:                1435.3378
# No. Observations:   367              Log-Likelihood:     -620.23
# Df Model:           32               F-statistic:        75.58
# Df Residuals:       334              Prob (F-statistic): 5.28e-133
# R-squared:          0.879            Scale:              1.8896
# -------------------------------------------------------------------
#                  Coef.   Std.Err.     t     P>|t|    [0.025  0.975]
# -------------------------------------------------------------------
# Intercept        1.7848    1.3558   1.3164  0.1889  -0.8822  4.4519
# school_lb        0.1823    0.2125   0.8577  0.3917  -0.2358  0.6004
# sex_lb           0.1191    0.1668   0.7141  0.4757  -0.2089  0.4471
# ...

# %%
form3 = gfx.form_model(df2, var_obj = 'G3')
lineal_model3 = smf.ols(form3 ,data = df2).fit()
lineal_model3.summary2()
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                  Results: Ordinary least squares
# ...
# Model:              OLS              Adj. R-squared:     0.826
# Dependent Variable: G3               AIC:                1546.9205
# Date:               2022-09-30 21:36 BIC:                1675.7975
# No. Observations:   367              Log-Likelihood:     -740.46
# Df Model:           32               F-statistic:        55.31
# Df Residuals:       334              Prob (F-statistic): 8.37e-114
# R-squared:          0.841            Scale:              3.6384
# -------------------------------------------------------------------
#                  Coef.   Std.Err.     t     P>|t|    [0.025  0.975]
# -------------------------------------------------------------------
# Intercept       -0.5227    1.8861  -0.2771  0.7819  -4.2327  3.1874
# school_lb        0.0699    0.2952   0.2368  0.8130  -0.5108  0.6506
# sex_lb          -0.0671    0.2316  -0.2896  0.7723  -0.5225  0.3884
# ...

# %%
df3 = df2.loc[:, ['school_lb','Pstatus_lb','Fedu_lb','activities_lb','famrel_lb','Dalc_lb','Walc_lb','age','failures','goout','absences','G1','G2','G3']]
df3.head()
# Out:
#    school_lb  Pstatus_lb  Fedu_lb  activities_lb  famrel_lb  Dalc_lb  Walc_lb  \
# 1          0           1        1              0          4        0        0
# 3          0           1        2              1          2        0        0
# 5          0           1        3              1          4        0        1
# 6          0           1        2              0          3        0        0
# 7          0           0        4              0          3        0        0
#
#     age  failures  goout  absences    G1  G2    G3
# 1  17.0       0.0    3.0       4.0   5.0   5   6.0
# 3  15.0       0.0    2.0       2.0  15.0  14  15.0
# 5  16.0       0.0    2.0      10.0  15.0  15  15.0
# 6  16.0       0.0    4.0       0.0  12.0  12  11.0
# 7  17.0       0.0    4.0       6.0   6.0   5   6.0

# %%
form3 = gfx.form_model(df3, var_obj = 'G3')
form3
lineal_model3 = smf.ols(form3 ,data = df3).fit()
lineal_model3.summary2()
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                  Results: Ordinary least squares
# ...
# Model:              OLS              Adj. R-squared:     0.830
# Dependent Variable: G3               AIC:                1519.7865
# Date:               2022-09-30 21:36 BIC:                1574.4615
# No. Observations:   367              Log-Likelihood:     -745.89
# Df Model:           13               F-statistic:        138.9
# Df Residuals:       353              Prob (F-statistic): 5.11e-130
# R-squared:          0.836            Scale:              3.5460
# -------------------------------------------------------------------
#                 Coef.   Std.Err.     t     P>|t|    [0.025   0.975]
# -------------------------------------------------------------------
# Intercept       0.4406    1.5791   0.2791  0.7804  -2.6649   3.5462
# school_lb       0.0421    0.2747   0.1532  0.8784  -0.4981   0.5823
# Pstatus_lb     -0.1995    0.3114  -0.6406  0.5222  -0.8119   0.4129
# ...

# %% [markdown]
# ### Modelación descriptiva

# %%
# eliminamos individuos que presentan valores perdidos
df = df.dropna()
df.head()
# Out:
#   school sex   age address famsize Pstatus Medu Fedu      Mjob      Fjob  ...  \
# 1     GP   F  17.0       U     GT3       T    1    1   at_home     other  ...
# 3     GP   F  15.0       U     GT3       T    4    2    health  services  ...
# 5     GP   M  16.0       U     LE3       T    4    3  services     other  ...
# 6     GP   M  16.0       U     LE3       T    2    2     other     other  ...
# 7     GP   F  17.0       U     GT3       A    4    4     other   teacher  ...
#
#   paid_lb activities_lb nursery_lb higher_lb  internet_lb romantic_lb  \
# 1       0             0          0         1            1           0
# 3       1             1          1         1            1           1
# 5       1             1          1         1            1           0
# 6       0             0          1         1            1           0
# 7       0             0          1         1            0           0
#
#   famrel_lb freetime_lb Dalc_lb Walc_lb
# ...

# %%
# seleccionamos preguntas ambientales
df_ambient = df.loc[:, ['famrel', 'freetime', 'goout', 'Dalc', 'Walc', 'health']]
df_ambient.head()
# Out:
#   famrel freetime  goout Dalc Walc  health
# 1      5        3    3.0    1    1     3.0
# 3      3        2    2.0    1    1     5.0
# 5      5        4    2.0    1    2     5.0
# 6      4        4    4.0    1    1     3.0
# 7      4        1    4.0    1    1     1.0

# %%
df_ambient.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 284 entries, 1 to 394
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   famrel    284 non-null    object
#  1   freetime  284 non-null    object
#  2   goout     284 non-null    float64
#  3   Dalc      284 non-null    object
#  4   Walc      284 non-null    object
#  5   health    284 non-null    float64
# dtypes: float64(2), object(4)
# memory usage: 15.5+ KB

# %%
# Funcion para ajustar los valores de los factores
for col in df_ambient.columns:
        try:
                df_ambient[col] = df_ambient[col].astype(int)
        except:
                df_ambient[col] = df_ambient[col].astype(float)

# %%
# calculamos
factor.calculate_bartlett_sphericity(df_ambient)
# Out:
# (258.56840355580005, 2.126748457334603e-46)

# %%
factors_ = factor.calculate_kmo(df_ambient)[0]

# %%
pd.DataFrame(data = {'variable': df_ambient.columns, 'KMO': factors_})
# Out:
#    variable       KMO
# 0    famrel  0.503497
# 1  freetime  0.578644
# 2     goout  0.618506
# 3      Dalc  0.588351
# 4      Walc  0.557151
# 5    health  0.594361

# %%
binary_dict = {'yes': 1, 'no': 0}

# %%
for col in ['schoolsup', 'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet', 'romantic']:
        df[col] = df[col].replace(binary_dict)

for col in ['goout', 'health']:
        df[col] = df[col].astype(str)

for col in ['G1', 'G3']:
        df[col] = df[col].astype(int)

# %%
df_dummies = pd.get_dummies(df, drop_first=True)
df_dummies.columns = [col.replace('-', '_') for col in df_dummies.columns]
df_dummies.head()
# Out:
#     age  failures  schoolsup  famsup  paid  activities  nursery  higher  \
# 1  17.0       0.0          0       1     0           0        0       1
# 3  15.0       0.0          0       1     1           1        1       1
# 5  16.0       0.0          0       1     1           1        1       1
# 6  16.0       0.0          0       0     0           0        1       1
# 7  17.0       0.0          1       1     0           0        1       1
#
#    internet  romantic  ...  Dalc_4  Dalc_5  Walc_2  Walc_3  Walc_4  Walc_5  \
# 1         1         0  ...       0       0       0       0       0       0
# 3         1         1  ...       0       0       0       0       0       0
# 5         1         0  ...       0       0       1       0       0       0
# 6         1         0  ...       0       0       0       0       0       0
# 7         0         0  ...       0       0       0       0       0       0
#
#    health_2.0  health_3.0  health_4.0  health_5.0
# ...

# %%
# reemplazo de nombres dummies que se generaron a partir de variables float
df_dummies.columns = df_dummies.columns.str.replace('.0', '')

# %%
# eliminamos V.O's de acuerdo al promedio a estimar
df_dummies_g1 = df_dummies.drop(['G2', 'G3'], axis=1)
df_dummies_g2 = df_dummies.drop(['G1', 'G3'], axis=1)

# %% [markdown]
# ### OLS - G1

# %%
# construimos formula para el modelo OLS de statsmodels y ajustamos
formula_g1_1 = gfx.form_model(df_dummies_g1, var_obj='G1')
model_g1_1 = smf.ols(formula_g1_1, data=df_dummies_g1).fit()
model_g1_1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                     G1   R-squared:                       0.431
# Model:                            OLS   Adj. R-squared:                  0.254
# Method:                 Least Squares   F-statistic:                     2.439
# Date:                Fri, 30 Sep 2022   Prob (F-statistic):           6.31e-07
# Time:                        21:36:27   Log-Likelihood:                -660.62
# No. Observations:                 284   AIC:                             1457.
# Df Residuals:                     216   BIC:                             1705.
# Df Model:                          67
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
df_g1 = ['failures', 'schoolsup', 'famsup', 'studytime_3', 'studytime_4', 'freetime_2', 'freetime_4', 
        'freetime_5', 'goout_3', 'goout_4', 'goout_5', 'health_3', 'health_4', 'health_5', 'G1']
df_def_g1 = df_dummies_g1.loc[:, df_g1]

# %%
base_formula_g1_2 = gfx.form_model(df_def_g1, var_obj='G1')
model_g1_2 = smf.ols(base_formula_g1_2, data=df_def_g1).fit()
model_g1_2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                     G1   R-squared:                       0.290
# Model:                            OLS   Adj. R-squared:                  0.253
# Method:                 Least Squares   F-statistic:                     7.832
# Date:                Fri, 30 Sep 2022   Prob (F-statistic):           6.77e-14
# Time:                        21:36:27   Log-Likelihood:                -692.07
# No. Observations:                 284   AIC:                             1414.
# Df Residuals:                     269   BIC:                             1469.
# Df Model:                          14
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      12.7422      0.573     22.246      0.000      11.614      13.870
# ...

# %% [markdown]
# ### OLS - G2

# %%
# ajuste G2
formula_g2_1 = gfx.form_model(df_dummies_g2, var_obj='G2')
model_g2_1 = smf.ols(formula_g2_1, data=df_dummies_g2).fit()
model_g2_1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                     G2   R-squared:                       0.398
# Model:                            OLS   Adj. R-squared:                  0.211
# Method:                 Least Squares   F-statistic:                     2.127
# Date:                Fri, 30 Sep 2022   Prob (F-statistic):           2.33e-05
# Time:                        21:36:27   Log-Likelihood:                -708.86
# No. Observations:                 284   AIC:                             1554.
# Df Residuals:                     216   BIC:                             1802.
# Df Model:                          67
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
df_g2 = ['failures', 'famsup', 'freetime_5', 'goout_4', 'goout_5', 'Walc_5', 'health_3', 'health_4', 'health_5', 'G2']
df_def_g2 = df_dummies_g2.loc[:, df_g2]

# %%
formula_g2_2 = gfx.form_model(df_def_g2, var_obj='G2')
model_g2_2 = smf.ols(formula_g2_2, data=df_def_g2).fit()
model_g2_2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                     G2   R-squared:                       0.211
# Model:                            OLS   Adj. R-squared:                  0.185
# Method:                 Least Squares   F-statistic:                     8.152
# Date:                Fri, 30 Sep 2022   Prob (F-statistic):           1.00e-10
# Time:                        21:36:27   Log-Likelihood:                -747.12
# No. Observations:                 284   AIC:                             1514.
# Df Residuals:                     274   BIC:                             1551.
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     13.4504      0.558     24.107      0.000      12.352      14.549
# ...

# %%
# seleccionamos variables para utilizar en los modelos
df_vars = ['failures', 'schoolsup', 'studytime_3', 'freetime_2', 'freetime_5', 'goout_4', 'goout_5', 'health_3', 'health_4', 'health_5', 'G3']
df_pred = df_dummies.loc[:, df_vars]

# %% [markdown]
# ## Modelacion predictiva
#
# ### Modelo 1

# %%
# separamos variable objetivo del conjunto de datos
mat_atr = df_pred.drop('G3', axis=1)
vec_obj = df_pred.loc[:, 'G3']

# %%
# split de conjuntos de entrenamiento vs prueba
X_train, X_test, y_train, y_test = train_test_split(mat_atr, vec_obj, test_size=.33, random_state=15820)

# %%
# ajustamos modelo sin alterar hiperparámetros
modelo_1 =  LinearRegression(fit_intercept=True).fit(X_train, y_train)

# %%
# predecimos el vector objetivo
y_hat = modelo_1.predict(X_test)

# %%
# obtenemos métricas
gfx.report_scores(y_hat, y_test)
# Out:
# Error cuadrático medio: 19.935660944070836
# R2: 0.05

# %% [markdown]
# ### Modelo 2

# %%
# separamos variable objetivo del conjunto de datos
mat_atr = df_pred.drop('G3', axis=1)
vec_obj = df_pred.loc[:, 'G3']

# %%
# agregamos failures al cuadrado
mat_atr1 = mat_atr.copy()
mat_atr1['failures_2'] = mat_atr1['failures'] ** 2

# %%
# split de conjuntos de entrenamiento vs prueba
X_train1, X_test1, y_train1, y_test1 = train_test_split(mat_atr1, vec_obj, test_size=.33, random_state=15820)

# %%
# ajustamos modelo sin alterar hiperparámetros
modelo_2 =  LinearRegression(fit_intercept=True).fit(X_train1, y_train1)

# %%
# predecimos el vector objetivo
y_hat1 = modelo_2.predict(X_test1)

# %%
# obtenemos métricas
gfx.report_scores(y_hat1, y_test1)
# Out:
# Error cuadrático medio: 20.048442719094687
# R2: 0.04
